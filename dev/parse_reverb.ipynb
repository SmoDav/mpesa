# %%
### this file is used to add sentiment polarity in existing dataframe
### input: pandas dataframe with date, news title, news content 

import pandas as pd
from textblob import TextBlob
import sys  
import datetime as dt
from dateutil.parser import parse
reload(sys)  
sys.setdefaultencoding('utf8')
def senti():
	ticker, data=parse_1()
	Polarity = map(lambda x: TextBlob(x),data.content)
	result=[]
	for i in range(len(Polarity)):
		k = Polarity[i].sentiment.polarity
		result.append(k)
	data['polarity']=result
	df=date_transform(data)
	####################transform data to standard structure###############
	return ticker,data

def parse_1():
	Ticker=raw_input('please input ticker: ')
	data=open('../data/'+Ticker+'.csv')
	array=data.read().split('|')
	date=[]
	content=[]
	for i in range(2,len(array)-1):
		if len(array[i])<30:
			date.append(array[i])
		else:
			content.append(array[i])
	dic={}
	dic['date']=date
	dic['content']=content
	df=pd.DataFrame(dic)
	return Ticker,df

def date_transform(df):
	date=df.date
	y=range(2007,2017)
	year=map(lambda x: str(x), y)

	
	real_date=[]
	for i in range(len(date)):
		if any(word in date[i] for word in year):
			d=date[i].split(',')[0]+date[i].split(',')[1]
			dat=parse(d).strftime('%-m/%-d/%y')
		####has year#####
			real_date.append(dat)
		else:
			d=date[i].split(',')[1]+' 2017'
			dat=parse(d).strftime('%-m/%-d/%y')
			real_date.append(dat)
	j=0
	while ':' in real_date[j]:
		j=j+1
	df.date=real_date
	df=df.iloc[j:,:]
	return df
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-f8a4027e976a> in <module>()
#       3
#       4 import pandas as pd
# ----> 5 from textblob import TextBlob
#       6 import sys
#       7 import datetime as dt
#
# ImportError: No module named textblob

# %%
ticker="BAC"
market_data=pd.read_csv('../data/Price/'+ticker+'.csv',header=0)

# %%
def parse_1(Ticker):
	data=open('../data/'+Ticker+'.csv')
	array=data.read().split('|')
	date=[]
	content=[]
	for i in range(2,len(array)-1):
		if len(array[i])<30:
			date.append(array[i])
		else:
			content.append(array[i])
	dic={}
	dic['date']=date
	dic['content']=content
	df=pd.DataFrame(dic)
	return Ticker,df

# %%
ticker,df=parse_1()

# %%
from dateutil.parser import parse
def date_transform(df):
	date=df.date
	y=range(2007,2017)
	year=map(lambda x: str(x), y)

	
	real_date=[]
	for i in range(len(date)):
		if any(word in date[i] for word in year):
			d=date[i].split(',')[0]+date[i].split(',')[1]
			dat=parse(d).strftime('%-m/%-d/%y')
		####has year#####
			real_date.append(dat)
		else:
			d=date[i].split(',')[1]+' 2017'
			dat=parse(d).strftime('%-m/%-d/%y')
			real_date.append(dat)
	j=0
	while ':' in real_date[j]:
		j=j+1
	df.date=real_date
	df=df.iloc[j:,:]
	return df

# %%
df=date_transform(df)

# %%
df=market_data.merge(df,how='left',left_on='Date',right_on='date').drop('date',axis=1)

# %%
return_=[]
for i in range(market_data.shape[0]-1):
    return_.append(market_data.iloc[i+1,1]/market_data.iloc[i,1]-1.0)
date=market_data.Date[1:]
df={}
return_5=return_[:-5]
return_4=return_[1:-4]
return_3=return_[2:-3]
return_2=return_[3:-2]
return_1=return_[4:-1]
return_y=return_[5:]
df['return_5']=return_5
df['return_4']=return_4
df['return_3']=return_3
df['return_2']=return_2
df['return_1']=return_1
df['return_y']=map(lambda x: 1 if x>=0 else 0,return_y)
df['Date']=date[5:]
dataframe=pd.DataFrame(df)
common_data=pd.read_csv('../data/Price/common_data.csv',header=0)
final=dataframe.merge(common_data,how='left',on='Date')

# %%
TickerList=["AA","AAPL","ABT","AMAT","BAC","BBBY","C","CAT","CHK","D","DOW","F","FCX","GE","JNJ","JNPR","K",\
            "KO","LLY","LMT","MCD","PG","PPL","RF","SLB","SO","T","VOD","VZ","XOM"]

# %%
Ticker,df=parse_1("AA")

# %%
A=list(df.content)

# %%
A.append(list(parse_1("AAPL")[1].content))

# %%
from gensim.models import Word2Vec

# %%
data=pd.read_csv('../data/reverb/AAreverb.csv',header=0)

# %%
sentences = [['first#', '','fdsab','sentence'], ['second', 'sentence']]
model = Word2Vec(sentences, min_count=1,size=200)

# %%
A=data.loc[:,['subject','object','verb']].fillna('')

# %%
A.iloc[0,2]
# Out:
# 'attribute to'

# %%
def trainset(df):
    all_sentence=[]
    for i in range(df.shape[0]):
        sentence=[]
        for j in range(df.shape[1]):
            string=str(df.iloc[i,j])
            if len(string)!=0:
                sentence+=string.split(' ')
        all_sentence.append(sentence)
    return all_sentence

# %%
train_set=trainset(A)

# %%
model = Word2Vec(train_set, min_count=1,size=100)

# %%
AllLis=[]
for each in train_set:
    lis=[0]*100
    if len(each)!=0:
        for each_word in each:
            lis+=model.wv[each_word]
        lis/=len(each)
    AllLis.append(lis)

# %%
pd.DataFrame(AllLis)
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.002921 -0.001036 -0.000465 -0.000223  0.000411  0.000494  0.001013
# 1    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2    0.002161 -0.002995  0.001138 -0.000496  0.000124  0.000002  0.000950
# 3    0.006419 -0.001053 -0.000405  0.001991 -0.001754 -0.000006  0.001709
# 4    0.004612 -0.001301  0.000479 -0.000429  0.000739 -0.000297 -0.000271
# 5    0.005100  0.000173  0.001038  0.002583  0.000413  0.000764 -0.000129
# 6    0.006298 -0.002978  0.001562  0.001506 -0.000283  0.000838 -0.000798
# 7    0.000320  0.000912  0.001450  0.002647 -0.001498  0.002197 -0.001770
# 8    0.002935 -0.001766  0.000518 -0.000611 -0.001244  0.001301 -0.000705
# 9    0.004364 -0.002960 -0.000573 -0.000410  0.001074  0.000281  0.000960
# 10   0.004734  0.000209  0.000625  0.003674 -0.000879  0.000725 -0.000137
# 11   0.002822 -0.000669 -0.001775  0.000211 -0.002161 -0.000064  0.000794
# 12   0.003728 -0.000310  0.002102  0.002508  0.000023 -0.001478 -0.000884
# 13   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 14   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 15   0.005862 -0.001409  0.001013  0.002933 -0.001531 -0.000448  0.000519
# 16   0.002460  0.000083  0.000283  0.001251  0.001545 -0.000620  0.000787
# 17   0.004231 -0.001033  0.000485  0.002252  0.000056 -0.000194 -0.001433
# 18   0.002437  0.000196 -0.000025  0.000180 -0.000793 -0.001203  0.000707
# 19   0.003367  0.000532 -0.001005  0.000262 -0.000086 -0.000974 -0.001459
# 20   0.002863 -0.001345  0.000424  0.001838  0.000700 -0.000784 -0.000419
# 21   0.003824 -0.000874 -0.001472  0.002034 -0.002695  0.001423  0.000082
# 22   0.004833 -0.001882 -0.000566  0.002188 -0.000932  0.001181  0.000299
# 23   0.007621 -0.003476 -0.001118  0.003046  0.001116 -0.000801  0.001546
# 24   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 
0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 25   0.002173 -0.001036  0.000061  0.001209  0.001686 -0.003157  0.002042
# 26   0.002066  0.001132 -0.003601  0.000333  0.002496 -0.004457  0.000854
# 27   0.002193  0.001252 -0.002105  0.000898  0.001837 -0.002527  0.000634
# 28   0.001245 -0.000440 -0.003073  0.000101  0.001982 -0.001491 -0.000431
# 29   0.000953 -0.000014 -0.000475  0.001197  0.001143 -0.002313  0.003132
# ..        ...       ...       ...       ...       ...       ...       ...
# 914  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 915  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 916  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 917  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 918  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 919  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 920  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 921  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 922  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 923  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 924  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 925  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 926  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 927  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 928  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 929  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 930  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 931  0.000055  0.000978 -0.002468  0.000024  0.002277 -0.003415  0.001516
# 932  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 933  0.000500  0.001813 -0.001598  0.000892  0.001647 -0.002162 -0.000630
# 934 -0.000817  0.002328 -0.002889  0.000289  0.000796 -0.004533  0.001310
# 935  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 936  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 937  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 938  0.001754 -0.002631 -0.002768 -0.001057 -0.000176 -0.003524  0.004186
# 939  0.001278  0.000982 -0.001308  0.000891  0.001759 -0.006361  0.001821
# 940  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 941  0.000850  0.001186 -0.000087 -0.001343  0.000246 -0.002564  0.002717
# 942  0.003171 -0.000494 -0.001673  0.000776  0.002044 -0.004753  0.003744
# 943  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [944 rows x 100 columns]

# %%
data
# Out:
#      Unnamed: 0                                            content  \
# 0             0  Global miners move higher as China affirms cap...
# 1             1  Alcoa upgraded to Buy at Goldman Sachs\n\n Alc...
# 2             2  China proposes capacity cuts in steel, coal\n\...
# 3             3  Alcoa combines business units, names Reyes to ...
# 4             4  Bloomberg: China orders steel, aluminum cuts t...
# 5             5  Infrastructure stocks jump after Trump speech\...
# 6             6  Aluminum stocks rise; Stifel sees prices up 16...
# 7             7  Trump promises "big statement" on infrastructu...
# 8             8  Report: Trump to push infrastructure spending ...
# 9             9  Alcoa gets two-notch upgrade to Buy from Under...
# 10           10  Alcoa +2% as JPMorgan climbs on board\n\nAlcoa...
# 11           11  Alcoa upgraded at Deutsche Bank, Citi after Q4...
# 12           12  Alcoa +1.5% as revenue beats estimates, sees h...
# 13           13  Alcoa misses by $0.05, beats on revenue\n\nAlc...
# 14           14  Notable earnings after Tuesday’s close\n\n AA,...
# 15           15  Alcoa to restart Portland aluminum smelter in ...
# 16           16  Steel stocks rally as Commerce nominee Ross si...
# 17           17  U.S. launches formal WTO complaint over Chines...
# 18           18  U.S. to launch WTO complaint against China ove...
# 19           19  Industrial metals stocks surge after China cut...
# 20           20  Australia offers financial support for cripple...
# 21           21  Alcoa to close Suralco alumina refinery, book ...
# 22           22  Alcoa says Australia aluminum smelter running ...
# 23           23  Alcoa upgraded at Macquarie as "best way" to p...
# 24           24  More gains ahead for Alcoa in 2017 even after ...
# 25           25  Teck Resources upgraded, Alcoa downgraded at C...
# 26           26  Alcoa assesses impact of power outage at Portl...
# 27           27  Commerce Department says China flouted aluminu...
# 28           28  Alcoa merits strong recommendation from Morgan...
# 29           29  Alcoa started at Neutral, Arconic spinoff at S...
# ..          ...                                                ...
# 914         914  Dow leaders: BAC +5.3%. HD +5.2%. C +4.8%. DIS...
# 915         915  Dow laggards: CVX -2.9%, AA -2.2%, XOM -1.9%. ...
# 916         916  Dow leaders: T +1.9%. AXP +1.7%. AA +1.7%. BAC...
# 917         917  Dow leaders: AA +1.2%, BA +0.9%, T +0.7%, XOM ...
# 918         918  Dow winners: None. Losers: AIG -5.5%. BAC -4.1...
# 919         919  Dow leaders: CVX +2.9%. XOM +2.4%. HD +2.3%. A...
# 920         920        Dow leaders: CVX +1.4%, AA +0.9%.
# 921         921  Dow leaders: HPQ +5.3%. CVX +2.3%. BAC +2.1%. ...
# 922         922       Dow leaders: HPQ +3.7%, CVX +1.2%, AA +1.1%.
# 923         923  Dow strength: XOM +1.8%. CVX +1.8%. AA +0.5%. ...
# 924         924  Dow leaders: XOM +1.1%. CXV +1.0%. AA +0.8%. B...
# 925         925  Dow laggards: T -1.4%. AA -1.3%. WMT -1.0%. VZ...
# 926         926  Dow leaders: AA +4.4%. CVX +2.6%. XOM +1.4%. I...
# 927         927  Dow leaders: HD +4.25%. AXP +3.5%. C +3%. DIS ...
# 928         928  Dow leaders after the first 1/2 hour. AA +3%. ...
# 929         929  Dow leaders: AIG +5.4%. GM +3.3%. BA +3.3%. BA...
# 930         930  Dow leaders: PFE +2.15%. WMT +1.7%. PG +1.7%. ...
# 931         931  Siemens (SI) sues 2 former CEOs (including AA ...
# 932         932  Dow laggards: KO -3.9%. AA -2.4%. WMT -1.9%.  ...
# 933         933  "Energy costs and input prices have continued ...
# 934         934  Alcoa (AA): EPS of $0.66 is in line. Revenue o...
# 935         935  Dow leaders: PFE +3.4%. BAC +3.1%. GE +2.3%. W...
# 936         936  Earnings of note Tuesday pre-open: PBG, HELE, ...
# 937         937  Dow leaders: AA +2.8%. IBM +2.2%. GM +1.9%. HP...
# 938         938  Futures point to a mixed open. Investors edgy ...
# 939         939  GM's (GM +1.7%) market value is just $7.5B  - ...
# 940         940  Chinese aluminium giant Chinalco (ACH) may add...
# 941         941  Follow-up to Vale (RIO) approaching banks for ...
# 942         942  The Street fails to appreciate the effect of r...
# 943         943  Will U.S. dollar weakness lead to U.S. icons b...
#
#                         date  confidence                        subject  \
# 0     Mon, Mar. 13, 10:24 AM    0.969297              today 's strength
# 1       Mon, Mar. 6, 8:53 AM    0.000000                            NaN
# 2       Mon, Mar. 6, 8:14 AM    0.754846           this year.no mention
# 3      Thu, Mar. 2, 10:06 AM    0.960803         aa 's # business units
# 4       Wed, Mar. 1, 5:25 PM    0.893766   shares of aluminum companies
# 5       Wed, Mar. 1, 9:27 AM    0.913916                        clf # %
# 6      Mon, Feb. 27, 5:28 PM    0.727173                       the firm
# 7     Mon, Feb. 27, 10:59 AM    0.939647  infrastructure related stocks
# 8     Thu, Feb. 23, 11:36 AM    0.743982              the axios website
# 9       Fri, Feb. 3, 3:55 PM    0.868534                          alcoa
# 10      Thu, Feb. 2, 7:38 AM    0.137104     another # % upside .shares
# 11     Wed, Jan. 25, 8:51 AM    0.559091               commodity prices
# 12     Tue, Jan. 24, 5:47 PM    0.844939                    the company
# 13     Tue, Jan. 24, 4:12 PM    0.000000                            NaN
# 14     Mon, Jan. 23, 5:35 PM    0.000000                            NaN
# 15     Thu, Jan. 19, 5:57 PM    0.732529        the smelter.the smelter
# 16    Wed, Jan. 18, 12:38 PM    0.901012                      last week
# 17    Thu, Jan. 12, 12:59 PM    0.835196               century aluminum
# 18     Wed, Jan. 11, 6:22 PM    0.902409                  the complaint
# 19     Tue, Jan. 10, 2:27 PM    0.927546                producer prices
# 20      Mon, Jan. 9, 7:56 AM    0.909754                       aluminum
# 21      Tue, Jan. 3, 5:14 PM    0.656727                        results
# 22   Dec. 21, 2016, 10:33 AM    0.757746                      the plant
# 23   Dec. 20, 2016, 11:42 AM    0.852760                          alcoa
# 24    Dec. 15, 2016, 5:58 PM    0.000000                            NaN
# 25     Dec. 5, 2016, 1:57 PM    0.921682                        neutral
# 26    Dec. 5, 2016, 12:57 PM    0.979664         a power interconnector
# 27     Nov. 8, 2016, 9:57 AM    0.870045                        the doc
# 28    Nov. 7, 2016, 11:41 AM    0.716778                          alcoa
# 29     Nov. 2, 2016, 3:31 PM    0.979914                  goldman sachs
# ..                       ...         ...                            ...
# 914    Sep. 8, 2008, 1:15 PM    0.000000                            NaN
# 915   Sep. 2, 2008, 10:02 AM    0.000000                            NaN
# 916   Aug. 27, 2008, 3:17 PM    0.000000                            NaN
# 917  Aug. 27, 2008, 10:16 AM    0.000000                            NaN
# 918   Aug. 25, 2008, 4:11 PM    0.000000                            NaN
# 919   Aug. 21, 2008, 3:00 PM    0.000000                            NaN
# 920  Aug. 21, 2008, 10:19 AM    0.000000                            NaN
# 921   Aug. 20, 2008, 3:00 PM    0.000000                            NaN
# 922  Aug. 20, 2008, 10:13 AM    0.000000                            NaN
# 923   Aug. 19, 2008, 3:02 PM    0.000000                            NaN
# 924   Aug. 18, 2008, 9:58 AM    0.000000                            NaN
# 925  Aug. 14, 2008, 10:05 AM    0.000000                            NaN
# 926   Aug. 13, 2008, 3:06 PM    0.000000                            NaN
# 927  Aug. 11, 2008, 12:02 PM    0.000000                            NaN
# 928   Aug. 6, 2008, 10:00 AM    0.000000                            NaN
# 929   Aug. 5, 2008, 10:18 AM    0.000000                            NaN
# 930    Aug. 4, 2008, 2:25 PM    0.000000                            NaN
# 931  Jul. 29, 2008, 11:33 AM    0.741818           the company millions
# 932  Jul. 17, 2008, 10:22 AM    0.000000                            NaN
# 933    Jul. 9, 2008, 2:21 AM    0.766269      energy supply constraints
# 934    Jul. 8, 2008, 4:42 PM    0.892902   the entire aluminum industry
# 935    Jul. 8, 2008, 2:05 PM    0.000000                            NaN
# 936    Jul. 8, 2008, 6:36 AM    0.000000                            NaN
# 937    Jul. 7, 2008, 3:43 PM    0.000000                            NaN
# 938    Jul. 7, 2008, 5:58 AM    0.774713                          alcoa
# 939   Jun. 24, 2008, 3:30 PM    0.595168                            $ #
# 940   Jun. 17, 2008, 7:33 AM    0.000000                            NaN
# 941   Jun. 10, 2008, 8:44 AM    0.844673                           vale
# 942    Jun. 8, 2008, 6:53 AM    0.894177                         shares
# 943    May 28, 2008, 2:15 PM    0.000000                            NaN
#
#                                               object  \
# 0                                    seasonal demand
# 1                                                NaN
# 2                                      aluminum cuts
# 3                                      alcoa bauxite
# 4                                     today 's trade
# 5                                                # %
# 6                                   its price target
# 7                                               pres
# 8                                 republican sources
# 9                             its second big upgrade
# 10                                     # % premarket
# 11                                            a boon
# 12             # % y/y global aluminum demand growth
# 13                                               NaN
# 14                                               NaN
# 15   # % of nameplate capacity of # metric tons/year
# 16                                           the wto
# 17                                               # %
# 18       tomorrow.other potentially relevant tickers
# 19                                          december
# 20        the 300k metric tons/year portland smelter
# 21                           the dec. # power outage
# 22                                           # weeks
# 23                                          the move
# 24                                               NaN
# 25                                               $ #
# 26                                          thursday
# 27                                   china zhongwang
# 28                              an overweight rating
# 29                                             alcoa
# ..                                               ...
# 914                                              NaN
# 915                                              NaN
# 916                                              NaN
# 917                                              NaN
# 918                                              NaN
# 919                                              NaN
# 920                                              NaN
# 921                                              NaN
# 922                                              NaN
# 923                                              NaN
# 924                                              NaN
# 925                                              NaN
# 926                                              NaN
# 927                                              NaN
# 928                                              NaN
# 929                                              NaN
# 930                                              NaN
# 931                                   its reputation
# 932                                              NaN
# 933                             smelter curtailments
# 934                                    higher volume
# 935                                              NaN
# 936                                              NaN
# 937                                              NaN
# 938                                  earnings season
# 939                                     the question
# 940                                              NaN
# 941                               # possible targets
# 942                                              $ #
# 943                                              NaN
#
#                             verb
# 0                   attribute to
# 1                            NaN
# 2                        make of
# 3                             be
# 4                        soar in
# 5                             de
# 6                          raise
# 7                   bounce after
# 8                           cite
# 9                           grab
# 10                            be
# 11                   prove to be
# 12                      forecast
# 13                           NaN
# 14                           NaN
# 15                    operate at
# 16           file complaint with
# 17                  jump much as
# 18                     unveil as
# 19                      surge in
# 20         disrupt production at
# 21        expect to be impact by
# 22                     knock out
# 23                         be on
# 24                           NaN
# 25                    raise from
# 26                         go on
# 27   initiate investigation into
# 28                 initiate with
# 29              offer praise for
# ..                           ...
# 914                          NaN
# 915                          NaN
# 916                          NaN
# 917                          NaN
# 918                          NaN
# 919                          NaN
# 920                          NaN
# 921                          NaN
# 922                          NaN
# 923                          NaN
# 924                          NaN
# 925                          NaN
# 926                          NaN
# 927                          NaN
# 928                          NaN
# 929                          NaN
# 930                          NaN
# 931                       damage
# 932                          NaN
# 933                        cause
# 934                    offset by
# 935                          NaN
# 936                          NaN
# 937                          NaN
# 938                     kick off
# 939                          beg
# 940                          NaN
# 941                        study
# 942                     trade to
# 943                          NaN
#
# [944 rows x 7 columns]
